# %% [markdown]
# # Initial Setup

# %%
## Setup the path for our codebase
import sys
sys.path.append( '../code/' )

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Example Data (centered Quadratic)

# %%
import neural_network.simple as simple

# %%
data = simple.generate_hill_data(100)

# %%
xs = map(lambda z: z[0], data)
ys = map(lambda z: z[1], data)
plt.plot( xs, ys )

# %% [markdown]
# # Simple Feed-Foward 1-Layer Neural Networks

# %% [markdown]
# ### Ok, try having a simple 3-node 1-layer neural network

# %%
nn = simple.SimpleScalarF_1Layer(hidden_layer_size=3)
simple.plot_fits( nn, data, train_epochs=200 )
nn.visualize_inputs_to_final_layer(data)

# %% [markdown]
# ### hmm, maybe not enough hidden nodes to get the nonlinearity, try 10

# %%
nn = simple.SimpleScalarF_1Layer(hidden_layer_size=10)
simple.plot_fits( nn, data, train_epochs=200 )
nn.visualize_inputs_to_final_layer(data)

# %% [markdown]
# ### Ok, it learned better and faster, let's see fewer training epochs per line

# %%
nn = simple.SimpleScalarF_1Layer(hidden_layer_size=10,learning_rate=0.001)
simple.plot_fits( nn, data, train_epochs=20 )
nn.visualize_inputs_to_final_layer(data)

# %% [markdown]
# ### WTF? ... oh, right .... we are using a *local optimizer* so we get local optima :-)

# %%
nn = simple.SimpleScalarF_1Layer(hidden_layer_size=10,learning_rate=0.001)
simple.plot_fits( nn, data, train_epochs=20 )
nn.visualize_inputs_to_final_layer(data)

# %%
nn = simple.SimpleScalarF_1Layer(hidden_layer_size=10,learning_rate=0.001)
simple.plot_fits( nn, data, train_epochs=2000 )
nn.visualize_inputs_to_final_layer(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7acb2d8ea0b8> in <module>()
#       1 nn = simple.SimpleScalarF_1Layer(hidden_layer_size=10,learning_rate=0.001)
# ----> 2 simple.plot_fits( nn, data, train_epochs=2000 )
#       3 nn.visualize_inputs_to_final_layer(data)
#
# C:\Users\josh\Documents\GitHub\ml-chats\time_series\code\neural_network\simple.py in plot_fits(nn, data, train_epochs, num_iterations)
#     202         nn.train( data,
#     203                   min_epochs = train_epochs,
# --> 204                   max_epochs = train_epochs )
#     205
#     206         regs.append( nn.regress( xs ) )
#
# C:\Users\josh\Documents\GitHub\ml-chats\time_series\code\neural_network\simple.py in train(self, data, max_epochs, min_epochs)
#      64
#      65                 # update weights for input
# ---> 66                 self.update_weights_using_gradient_learning( x, y )
#      67
#      68
#
# C:\Users\josh\Documents\GitHub\ml-chats\time_series\code\neural_network\simple.py in update_weights_using_gradient_learning(self, x, y)
#     145             sig_a = scipy.special.expit( a[h_i] )
#     146             deriv_a = sig_a * (1.0 - sig_a)
# --> 147             d1[h_i] = d2 * self.w[h_i] * deriv_a
#     148
#     149         # Ok, we now have the gradient, so move in the opposite
#
# KeyboardInterrupt:
